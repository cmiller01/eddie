# %%
# some imports
import pandas as pd

# %%
school_info = pd.read_csv('pubschls.txt', sep='\t', header=0)

# %%
school_info
# Out:
#               CDSCode NCESDist NCESSchool StatusType   County  \
# 0       1100170000000  0691051    No Data     Active  Alameda
# 1       1100170109835  0691051      10546     Closed  Alameda
# 2       1100170112607  0691051      10947     Active  Alameda
# 3       1100170118489  0691051      12283     Closed  Alameda
# 4       1100170123968  0691051      12844     Active  Alameda
# ...               ...      ...        ...        ...      ...
# 18274  58727690133751  0642350      14385     Active     Yuba
# 18275  58727695830039  0642350    No Data     Closed     Yuba
# 18276  58727695830070  0642350    No Data     Closed     Yuba
# 18277  58727695830120  0642350      08437     Closed     Yuba
# 18278  58727695838305  0642350      06930     Active     Yuba
#
#                                  District  \
# 0      Alameda County Office of Education
# 1      Alameda County Office of Education
# 2      Alameda County Office of Education
# 3      Alameda County Office of Education
# ...

# %%
school_info.query("School.str.contains('Mira Vista')",engine='python')
# Out:
#             CDSCode NCESDist NCESSchool StatusType        County  \
# 1490  7617966004857  0632550      05044     Active  Contra Costa
#
#                        District                 School             Street  \
# 1490  West Contra Costa Unified  Mira Vista Elementary  6397 Hazel Avenue
#
#             StreetAbr      City  ... Virtual Magnet YearRoundYN  \
# 1490  6397 Hazel Ave.  Richmond  ...       C      N           N
#
#      FederalDFCDistrictID   Latitude   Longitude AdmFName  AdmLName  \
# 1490              No Data  37.940007  -122.31306  Gabriel  Chilcott
#
#                   AdmEmail  LastUpDate
# 1490  gchilcott@wccusd.net  08/13/2020
#
# [1 rows x 47 columns]

# %%
pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)
school_info.query('NCESDist == "0632550" and StatusType == "Active" and EILCode == "ELEM"')
# Out:
#             CDSCode NCESDist NCESSchool StatusType        County  \
# 1430  7617960110973  0632550      11576     Active  Contra Costa
# 1432  7617960116319  0632550      12839     Active  Contra Costa
# 1435  7617960129643  0632550      13753     Active  Contra Costa
# 1437  7617960132118  0632550      13891     Active  Contra Costa
# 1439  7617960135434  0632550      14119     Active  Contra Costa
# 1440  7617960136903  0632550      14227     Active  Contra Costa
# 1465  7617966004600  0632550      05009     Active  Contra Costa
# 1470  7617966004659  0632550      05014     Active  Contra Costa
# 1471  7617966004667  0632550      05015     Active  Contra Costa
# 1474  7617966004691  0632550      05020     Active  Contra Costa
# 1478  7617966004733  0632550      05026     Active  Contra Costa
# 1479  7617966004741  0632550      10022     Active  Contra Costa
# 1480  7617966004758  0632550      05029     Active  Contra Costa
# ...
